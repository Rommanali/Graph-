# %%
from matplotlib import pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt

x = [0,1,2,3,4,5,6,7,8]
y = [10,30,20,50,60,35,36,12,30]

plt.plot(x,y,color='#23d9d1',linestyle='--',marker='*',markerfacecolor='red',markersize='9')
plt.title('Graph')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')
